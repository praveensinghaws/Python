# %% [markdown]
# # 26.String Methods in Python (Part 2)

# %% [markdown]
# ![Screenshot 2024-01-24 072018.png](attachment:6c30a594-0882-4cd7-bb94-fce4b0f25152.png)

# %% [markdown]
# ![Screenshot 2024-01-24 072552.png](attachment:fe20b3cb-13e7-4acc-8e8a-bffa45ea409e.png)

# %% [markdown]
# ![Screenshot 2024-01-24 072951.png](attachment:1dd7f8a3-13ff-481f-a45a-887c3fd60f7c.png)

# %% [markdown]
# ![Screenshot 2024-01-24 073200.png](attachment:577cafdd-92a2-4861-83c3-5ed7e84305e5.png)

# %% [markdown]
# ![Screenshot 2024-01-24 073301.png](attachment:1538df59-a384-40a4-9985-274dc5e2e02d.png)

# %% [markdown]
# ![Screenshot 2024-01-24 074114.png](attachment:2c64fbb6-5a18-4b8f-ba0e-01524000b8c7.png)

# %% [markdown]
# ![Screenshot 2024-01-24 074158.png](attachment:75389b81-ced2-4ca3-b80a-880086ef213a.png)

# %%
"My name is Jaspreet".rstrip('my ')
# Out:
# 'My name is Jaspreet'

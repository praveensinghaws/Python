# %% [markdown]
# # 31.String Methods in Python (Part 7)

# %% [markdown]
# ![image.png](attachment:5591085d-dab8-4503-b475-eded1e4755d9.png)

# %% [markdown]
# ![image.png](attachment:c70a8d66-bfce-44fa-85fd-6ebfc2610ece.png)

# %% [markdown]
# ![image.png](attachment:3f7aa07b-c611-4927-b22c-41e90db3e8ff.png)

# %% [markdown]
# ![image.png](attachment:c13a132b-c401-4093-8061-706a6b9efe64.png)

# %% [markdown]
# ![image.png](attachment:501fcb47-40ab-40cf-8abc-612cc97104e5.png)

# %% [markdown]
# ![image.png](attachment:faea60eb-5194-411b-a7f9-8b61a925f1c5.png)

# %% [markdown]
# ![image.png](attachment:74d0e3a3-9fe5-42ee-ab08-27ad51eac80a.png)

# %% [markdown]
# ![image.png](attachment:966d1147-2077-4a8e-ae98-0b5e33c2492d.png)

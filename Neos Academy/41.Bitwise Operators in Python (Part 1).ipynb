# %% [markdown]
# # 41.Bitwise Operators in Python (Part 1)

# %% [markdown]
# ![image.png](attachment:d1dd9832-b3e0-4fc2-b316-134a58a350c6.png)

# %% [markdown]
# ![image.png](attachment:3ebd07d2-33c2-401b-9341-c1fe14f45cdd.png)

# %% [markdown]
# ![image.png](attachment:c7498281-d7b6-426b-9e45-7d2e2ecaa92d.png)

# %% [markdown]
# ![image.png](attachment:aa2ecf7d-d6bb-42e4-a430-279df30cc8e2.png)

# %% [markdown]
# ![image.png](attachment:dfd6b37d-b350-4c40-ba09-d75ddc57cd13.png)

# %% [markdown]
# ![image.png](attachment:ee6b4bbb-f528-40b1-96ec-78adfab5219b.png)

# %% [markdown]
# ![image.png](attachment:3ecd5c45-dd9c-458b-8c57-b41534cb31e2.png)

# %% [markdown]
# ![image.png](attachment:07fab975-ebc4-4dbc-936b-8b7c37297060.png)

# %% [markdown]
# ![image.png](attachment:274800ba-3dce-4e78-9733-55ac87ed545d.png)

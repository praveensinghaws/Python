# %% [markdown]
# # 42.Bitwise Operators in Python (Part 2)

# %% [markdown]
# ![image.png](attachment:491032fc-9f60-4748-94d7-bbe37cf6c4d5.png)

# %% [markdown]
# ![image.png](attachment:b5a5c036-468c-4e8f-af83-b05444675688.png)

# %% [markdown]
# ![image.png](attachment:351eb0fd-cd5a-4684-91b6-300c9e3de735.png)

# %% [markdown]
# ![image.png](attachment:578de9f4-75bb-45d8-a619-4c564078b12c.png)

# %% [markdown]
# ![image.png](attachment:7c616852-03e2-4ab0-a1cd-b175781c3494.png)

# %% [markdown]
# ![image.png](attachment:501e2b75-dddd-4fc4-b78a-51de0e253aa3.png)

# %% [markdown]
# ![image.png](attachment:3c832bf2-62be-4e08-b9d7-117fb88edae4.png)

# %% [markdown]
# ![image.png](attachment:482740f5-6982-47ee-9371-36e8f2f1264c.png)

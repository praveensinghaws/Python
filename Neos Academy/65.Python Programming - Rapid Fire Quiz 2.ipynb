# %% [markdown]
# # 65.Python Programming - Rapid Fire Quiz 2

# %% [markdown]
# ![image.png](attachment:2cae185b-8d82-4fc1-9779-d9ab3bc496e9.png)

# %% [markdown]
# ![image.png](attachment:c4a393f6-a18e-4bc3-86be-e61ab6cec0b2.png)

# %% [markdown]
# ![image.png](attachment:937b4086-6cbd-4c01-a62e-54949e43b042.png)

# %% [markdown]
# ![image.png](attachment:3b14d62f-c8cf-4bd6-a571-8d884d690df0.png)

# %% [markdown]
# ![image.png](attachment:49d8a932-2f3f-4efd-b5d1-dee63e09b11e.png)

# %% [markdown]
# ![image.png](attachment:6639a7b1-b35e-4493-932a-439c20a83c41.png)

# %% [markdown]
# ![image.png](attachment:aded2d63-066e-4e38-831e-2ef63a5385b2.png)

# %% [markdown]
# ![image.png](attachment:758bada2-afdd-4bb9-b81a-8e28a1bc7317.png)

# %% [markdown]
# ![image.png](attachment:f5019d5a-c6f3-4c5c-bb09-8c4eb1ba263e.png)

# %% [markdown]
# ![image.png](attachment:d95c3afe-e9fb-488a-9cd3-55e79e462cbf.png)

# %% [markdown]
# ![image.png](attachment:209f326a-ed92-485d-965a-d288bf63a02c.png)

# %% [markdown]
# ![image.png](attachment:7fba34b0-3f14-48b5-bf06-b125eb5c59b3.png)

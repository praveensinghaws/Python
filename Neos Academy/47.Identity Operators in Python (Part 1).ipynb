# %% [markdown]
# # 47.Identity Operators in Python (Part 1)

# %% [markdown]
# ![image.png](attachment:8ec089d3-7dfb-4f1b-9998-9d2f4e4d1802.png)

# %% [markdown]
# ![image.png](attachment:576d1dad-78df-4b28-89fa-45f2388d4e99.png)

# %% [markdown]
# ![image.png](attachment:1c33388e-305d-4396-a44d-bbe788c5a08c.png)

# %% [markdown]
# ![image.png](attachment:c91952f6-7955-41e2-8c41-d550e39715e0.png)

# %% [markdown]
# ![image.png](attachment:912b47bf-df4a-4f02-a535-e334bd75843d.png)

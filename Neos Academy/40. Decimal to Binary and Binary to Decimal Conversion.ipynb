# %% [markdown]
# # 40. Decimal to Binary and Binary to Decimal Conversion

# %% [markdown]
# ![image.png](attachment:d5f824ca-3c78-45ba-9bd5-f347b8cb5000.png)

# %% [markdown]
# ![image.png](attachment:ab13d5de-b10c-487b-8a2a-8369c00cabc1.png)

# %% [markdown]
# ![image.png](attachment:672eff12-428f-4138-a696-411e0d014031.png)

# %% [markdown]
# ![image.png](attachment:7f247db5-e9f1-4f56-8b91-005884aad44d.png)

# %% [markdown]
# ![image.png](attachment:3aba8417-3522-4a3b-b7c8-3308241991a7.png)

# %% [markdown]
# ![image.png](attachment:6a44057a-7675-40b8-bb66-ae179b9c70af.png)

# %% [markdown]
# ![image.png](attachment:505ecb8f-6dcd-4216-8d84-59e3a7686dea.png)

# %% [markdown]
# ![image.png](attachment:49161817-94dd-4c64-b2d8-353fd5ea84a0.png)

# %%
decimal_number = 158
binary_representation = bin(decimal_number)[2:]
print(f"The binary representation of {decimal_number} is: {binary_representation}")
# Out:
# The binary representation of 158 is: 10011110

# %%
binary_number = "110011"
decimal_representation = int(binary_number, 2)
print(f"The decimal representation of {binary_number} is: {decimal_representation}")
# Out:
# The decimal representation of 110011 is: 51

# %% [markdown]
# ![image.png](attachment:fc386804-fb5b-4728-95fe-2f030832865c.png)	51
# 1

# %% [markdown]
# # 68.Changing and Adding Dictionary Items in Python

# %% [markdown]
# ![image.png](attachment:b67e9334-e256-43d8-a5bc-739d9dc129f9.png)

# %% [markdown]
# ![image.png](attachment:a7730bf0-86ff-4c11-b12f-9e99d8deb45c.png)

# %% [markdown]
# ![image.png](attachment:fa13adec-2d8c-4e29-aa4b-9e0695e79998.png)

# %% [markdown]
# ![image.png](attachment:70d289e9-b71f-4419-86e7-129bc8365f03.png)

# %% [markdown]
# ![image.png](attachment:69ec92da-c7a9-4423-b6fa-d3d09901176c.png)

# %% [markdown]
# ![image.png](attachment:24d0b4a0-ee4d-45cd-b5ed-a28dd4561bca.png)

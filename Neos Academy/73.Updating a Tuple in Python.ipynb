# %% [markdown]
# # 73.Updating a Tuple in Python

# %% [markdown]
# ![image.png](attachment:85a6f017-169b-4499-9b65-33261313e840.png)

# %% [markdown]
# ![image.png](attachment:e9f91729-7812-4af0-a78e-f846b7688ee8.png)

# %% [markdown]
# ![image.png](attachment:d0e79aa5-b3ed-49a7-a8b9-9c8224d25c1b.png)

# %% [markdown]
# ![image.png](attachment:f4cbf64c-063e-48c0-9169-94f7084dd380.png)

# %% [markdown]
# ![image.png](attachment:c0201448-418a-45bb-a23f-3ba6c219f144.png)

# %% [markdown]
# ![image.png](attachment:d5a537dd-8a54-4455-9126-a50b20b2ed02.png)

# %% [markdown]
# # 92.for Loop with else in Python

# %% [markdown]
# ![image.png](attachment:b8f46efb-4858-4ac1-a689-0bd2e6bb6747.png)

# %% [markdown]
# ![image.png](attachment:4a4235aa-63c5-4ff3-8ba4-b4fb54151096.png)

# %% [markdown]
# ![image.png](attachment:3bdb4d72-4388-4d9b-a5f8-87b5f227113f.png)

# %% [markdown]
# ![image.png](attachment:bde79f03-d4ba-44dd-8c2d-f262bfcb3631.png)

# %% [markdown]
# Sure, here's the code with comments:
#
# ```python
# # Define a list of favorite languages
# fav_languages = ['Python', 'C', 'Java', 'Ruby']
#
# # Iterate over each language in the list
# for language in fav_languages:
#     # Check if the current language is 'Java'
#     if 'Java' == language:
#         # If 'Java' is found, print a message and break out of the loop
#         print('I like Java.')
#         break
# else:
#     # If 'Java' is not found after iterating through the entire list,
#     # print a message indicating that Java is not liked
#     print("I don't like Java")
# ```
#
# In this code:
# - We define a list `fav_languages` containing several programming languages.
# - We iterate over each language in the list using a `for` loop.
# - Inside the loop, we check if the current language is 'Java'.
# - If 'Java' is found, we print "I like Java." and break out of the loop.
# - If the loop completes without encountering 'Java', meaning 'Java' is not in the list, we execute the `else` block and print "I don't like Java".

# %% [markdown]
# In your code, you're iterating over the list `fav_languages`. For each language in the list, you're checking if the character 'R' is equal to the language itself, which doesn't seem to be the intended logic. Let's correct the code to properly check if the string 'Java' is present in the list:
#
# ```python
# fav_languages = ['Python', 'C', 'Java', 'Ruby']
#
# for language in fav_languages:
#     if 'Java' == language:
#         print('I like Java.')
#         break
# else:
#     print("I don't like Java")
# ```
#
# This corrected code will iterate over each element in the `fav_languages` list. If it finds the string 'Java', it will print "I like Java." and break out of the loop. If the loop completes without encountering 'Java', it will execute the `else` block and print "I don't like Java".

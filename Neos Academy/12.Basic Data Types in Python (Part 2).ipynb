# %% [markdown]
# # 12.Basic Data Types in Python (Part 2)

# %% [markdown]
# ![Screenshot 2024-01-21 053807.png](attachment:2c47ae0b-737f-4ae8-ac53-f0c95cf454fb.png)

# %% [markdown]
# ![Screenshot 2024-01-21 053902.png](attachment:6fab92a5-e567-46bd-8c4d-abc5f0bd4209.png)

# %% [markdown]
# ![Screenshot 2024-01-21 053721.png](attachment:a0a278bf-8b63-4ad7-93e5-12558cf1615c.png)

# %% [markdown]
# ![Screenshot 2024-01-21 054345.png](attachment:ea7d7e5b-2b28-484a-b980-d1eb1263b634.png)

# %% [markdown]
# # 34.Explicit Type Conversion in Python (Part 1)

# %% [markdown]
# ![image.png](attachment:02ea6e21-20ec-4f6c-9140-ec6911acbbba.png)

# %% [markdown]
# ![image.png](attachment:ea6dbc1c-73b6-40ef-bd65-600461e052a9.png)

# %% [markdown]
# ![image.png](attachment:4f7b5ec9-1d28-4d73-a4d5-fca36de13efe.png)

# %% [markdown]
# ![image.png](attachment:0df106f1-c55a-44b9-9bcc-03e01d4c7774.png)

# %% [markdown]
# ![image.png](attachment:99e5aca2-6eeb-4e89-8cda-69d92f346ef5.png)

# %% [markdown]
# ![image.png](attachment:3b7293fd-7ab9-437d-8aa5-c9b7e42bf3b8.png)

# %% [markdown]
# # 7.Python and Visual Studio Code Installation

# %% [markdown]
# ![Screenshot 2024-01-20 084455.png](attachment:1c722247-a362-483c-b64d-43514d066bff.png)

# %% [markdown]
# ![Screenshot 2024-01-20 084606.png](attachment:c4a61d59-bb2c-47f4-bc49-15f556dcff8e.png)

# %%
# Import the platform module for system-related information
import platform

# Get and print the Python version
print("Python version:", platform.python_version())
# Out:
# Python version: 3.12.1

# %% [markdown]
# ![Screenshot 2024-01-20 085032.png](attachment:a11a3421-4150-4e80-871d-2fcb63e9da0d.png)

# %% [markdown]
# # 67.Accessing Dictionary Items in Python

# %% [markdown]
# ![image.png](attachment:ea1daab6-fb90-4dbd-a8d7-50265659b05c.png)

# %% [markdown]
# ![image.png](attachment:6ffb8648-6190-4bf2-9f3d-1591767075a7.png)

# %% [markdown]
# ![image.png](attachment:3c903d40-72c5-4aa1-b6a1-5b0c4d4a6ab6.png)

# %% [markdown]
# ![image.png](attachment:d6d4ca8e-affe-4d97-8b35-9f89a58c9e76.png)

# %% [markdown]
# ![image.png](attachment:ac1b835d-4124-493f-b963-414a62bf864b.png)

# %% [markdown]
# ![image.png](attachment:3a341d1a-1eab-4e1a-9858-bfe5a4c54a11.png)

# %% [markdown]
# ![image.png](attachment:a7ecc3d7-5509-4870-88d7-d9a22c2df757.png)

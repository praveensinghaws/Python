# %% [markdown]
# # 33.Implicit Type Conversion in Python

# %% [markdown]
# ![image.png](attachment:a8c7d884-67d9-4035-8ff3-953d3cadeb76.png)

# %% [markdown]
# ![image.png](attachment:06cfda04-777c-451c-bcc7-bdb2543f8657.png)

# %% [markdown]
# ![image.png](attachment:b97cd9c0-e1bf-4614-a2b7-308d88af995e.png)

# %% [markdown]
# ![image.png](attachment:ed2fe8f8-8a7d-46c8-b467-91e2ba96868e.png)

# %% [markdown]
# ![image.png](attachment:451fdd42-b67e-49d5-aef3-a13d7711972b.png)

# %% [markdown]
# ![image.png](attachment:e68b9c8f-356c-4a03-ac1a-3ea7c2398639.png)

# %% [markdown]
# ![image.png](attachment:4f5b1842-3af5-4cc7-8f1e-b66bf4b0b065.png)

# %%
x = 10
y = 20
total = x + y
print("The total is : " + str(total))
# Out:
# The total is : 30

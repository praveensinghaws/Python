# %% [markdown]
# # 43.Bitwise Right Shift Operator in Python

# %% [markdown]
# ![image.png](attachment:e1f2e81e-17fc-4440-9b5f-82e1e4801889.png)

# %% [markdown]
# ![image.png](attachment:cf3dcde8-fed6-4a61-bcda-00f71b7c73e5.png)

# %% [markdown]
# ![image.png](attachment:d0961df1-e316-408f-bb8d-17f3e2d46fbd.png)

# %% [markdown]
# ![image.png](attachment:84bff003-54ea-4d01-9343-1eb7c3dc329e.png)

# %% [markdown]
# ![image.png](attachment:f0f3eedd-4425-4eda-9df8-c6105be7298a.png)

# %% [markdown]
# ![image.png](attachment:abe98ed4-040c-4bb4-a83c-83fc0b6fd892.png)

# %% [markdown]
# ![image.png](attachment:d4748c05-5946-4836-b037-b6cf601f775a.png)

# %% [markdown]
# ![image.png](attachment:0982d11e-8508-439f-91d0-878210540ee9.png)

# %% [markdown]
# ![image.png](attachment:2b40b1a8-3283-4c78-9df4-00e3959bfd48.png)

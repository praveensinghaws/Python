# %% [markdown]
# # 6.Is Python Compiled or Interpreted?

# %% [markdown]
# ![F (2).png](attachment:ad232d02-0764-4ef8-9e4f-0facf3a02dd0.png)

# %% [markdown]
# ![F (1).png](attachment:b9a9e900-2a2e-4430-b4ab-742c0f8a3c5b.png)

# %%
# Import the py_compile module for working with compiled Python files
import py_compile

# Specify the path to the compiled Python file
compiled_file_path = r'D:\GITHUB-REPO\Python\Neos Academy\__pycache__\neme.cpython-312.pyc'

# Print the path to the compiled file
print(compiled_file_path)
# Out:
# D:\GITHUB-REPO\Python\Neos Academy\__pycache__\neme.cpython-312.pyc

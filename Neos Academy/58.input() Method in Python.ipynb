# %% [markdown]
# # 58.input() Method in Python

# %% [markdown]
# ![image.png](attachment:9db04e84-a942-4580-94c8-2f95b146cf8c.png)

# %% [markdown]
# ![image.png](attachment:56f31a71-e33f-4520-8af7-a85a4d911849.png)

# %% [markdown]
# ![image.png](attachment:a87e5adb-cd34-4773-8e7f-7a4f9770d228.png)

# %% [markdown]
# ![image.png](attachment:f0f0855c-9e82-4e48-a965-ff2e6d0c618a.png)

# %% [markdown]
# ![image.png](attachment:ae199a10-5e38-4732-902b-f580a3ceb7fd.png)

# %% [markdown]
# ![image.png](attachment:da6497d5-bd37-4dcf-b08c-c239bddfd692.png)

# %% [markdown]
# ![image.png](attachment:c29c358d-6b3f-4813-bd47-787ee7264454.png)

# %%
# Prompt the user to enter a number and store the input in the variable 'number'
number = int(input('Enter a number:'))
number
# Out:
# Enter a number: 700
# 700

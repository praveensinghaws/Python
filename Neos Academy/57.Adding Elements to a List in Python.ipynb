# %% [markdown]
# # 57.Adding Elements to a List in Python

# %% [markdown]
# ![image.png](attachment:7a9518e4-c551-4c36-8d32-d3e5dd68b2c7.png)

# %% [markdown]
# ![image.png](attachment:96835804-09d2-46c3-956f-727a1be36514.png)

# %% [markdown]
# ![image.png](attachment:19998a6d-200c-4a4c-ac98-39e749d1cc54.png)

# %% [markdown]
# ![image.png](attachment:aabef4e0-40a8-4951-9987-da16847f28eb.png)

# %% [markdown]
# ![image.png](attachment:19c6ad49-5529-4216-aaf5-2cea9f3dc806.png)

# %% [markdown]
# ![image.png](attachment:2aa41ef2-a497-49ac-b7ec-41aab2e0bb21.png)

# %% [markdown]
# ![image.png](attachment:ae6c712f-c37f-4d38-b3cf-d777d2a35498.png)

# %% [markdown]
# ![image.png](attachment:b54d293a-dcbd-4d77-9e63-723d06874441.png)

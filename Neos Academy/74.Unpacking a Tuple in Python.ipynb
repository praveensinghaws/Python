# %% [markdown]
# # 74.Unpacking a Tuple in Python

# %% [markdown]
# ![image.png](attachment:4d299fae-b13b-4780-a159-827dd22ccde4.png)

# %% [markdown]
# ![image.png](attachment:8da968db-5d82-48b5-b0d1-6f31828055f4.png)

# %% [markdown]
# ![image.png](attachment:1bcfe477-ddc3-40d3-8f64-9c314aec5bd6.png)

# %% [markdown]
# ![image.png](attachment:6c2373fa-475b-4fba-b4e7-6c191917a8cf.png)

# %% [markdown]
# ![image.png](attachment:172c3825-e41f-4ec7-ab78-7398e9b5f0b9.png)

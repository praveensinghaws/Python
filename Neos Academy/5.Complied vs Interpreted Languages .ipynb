# %% [markdown]
# # 5.Complied vs Interpreted Languages

# %% [markdown]
# ![E (1).png](attachment:987550f5-5fd7-4e6f-b659-b3cd70b17477.png)

# %% [markdown]
# ![E (2).png](attachment:3c5d1fce-b3d5-4367-af6b-5c1e5e458bdd.png)

# %% [markdown]
# ![E (3).png](attachment:c237eb8a-192e-4062-9549-c17c3b56bbdb.png)

# %% [markdown]
# ![E (4).png](attachment:8d30610b-15ea-47bd-9be9-8e2e7f76d57a.png)

# %% [markdown]
# ![E (5).png](attachment:d8059956-30af-4e97-8a12-03342326445a.png)

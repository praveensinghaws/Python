# %% [markdown]
# # 96.for Loop vs. while Loop in Python

# %% [markdown]
# ![image.png](attachment:74b61411-865f-4f3d-aed1-10ee16dffb03.png)

# %% [markdown]
# ![image.png](attachment:be825b8d-5129-447f-b8a6-30aef1fa437b.png)

# %% [markdown]
# ![image.png](attachment:efea4ab2-1897-41f5-92e0-64724f63d169.png)

# %% [markdown]
# ![image.png](attachment:acbcd08b-9d43-460d-99da-fad6ca1679d9.png)

# %% [markdown]
# ![image.png](attachment:3e6b337e-7aba-4192-aa1d-fd8430b2c791.png)

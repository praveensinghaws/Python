# %% [markdown]
# # 44.Bitwise Left Shift Operator in Python

# %% [markdown]
# ![image.png](attachment:f72ec13e-8cfe-4161-b9c7-6bc1b53856ce.png)

# %% [markdown]
# ![image.png](attachment:0dc3eeae-6898-4d3c-92d4-32173620fcc1.png)

# %% [markdown]
# ![image.png](attachment:65340576-b1e0-46a5-927d-56ad2b38ee57.png)

# %% [markdown]
# ![image.png](attachment:f47ff3e7-4d61-45b0-a317-ca851a1f8d53.png)

# %% [markdown]
# ![image.png](attachment:7ee99b11-87ef-4bbe-a02c-de4a37e852d4.png)

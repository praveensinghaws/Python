# %% [markdown]
# # 72.Accessing Tuple Items in Python

# %% [markdown]
# ![image.png](attachment:61dc40ab-caf2-4208-b36a-dea630b4706a.png)

# %% [markdown]
# ![image.png](attachment:c9861787-06ae-4b7d-a68f-232353a9b51f.png)

# %% [markdown]
# ![image.png](attachment:77cadabd-9804-412d-a353-09f2c5649955.png)

# %% [markdown]
# ![image.png](attachment:0ef19bf8-c996-439f-84ec-665f1b8ffc8a.png)

# %% [markdown]
# ![image.png](attachment:adecd2d0-151e-4d65-9774-cdb225ec522d.png)

# %% [markdown]
# ![image.png](attachment:ae9a9907-68b4-4d14-81e8-a660460f312e.png)

# %% [markdown]
# ![image.png](attachment:813733c9-912f-45f8-8aa4-fadc0a407ae7.png)

# %% [markdown]
# ![image.png](attachment:2b23f294-322d-41fe-ba46-c8689380d14e.png)

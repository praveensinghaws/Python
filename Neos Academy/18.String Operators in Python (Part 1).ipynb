# %% [markdown]
# # 18.String Operators in Python (Part 1)

# %% [markdown]
# ![Screenshot 2024-01-21 071025.png](attachment:33c53090-77aa-493f-b85d-81a776a63efb.png)

# %% [markdown]
# ![Screenshot 2024-01-21 071402.png](attachment:96774783-d08f-4ec8-bfa6-5af619a47868.png)

# %% [markdown]
# ![Screenshot 2024-01-21 071734.png](attachment:7a77e0a5-98c9-4766-acbe-c4211c1d18e4.png)

# %% [markdown]
# ![Screenshot 2024-01-21 071910.png](attachment:d2cf7791-8af5-428d-b05f-608e7893b702.png)

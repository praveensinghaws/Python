# %% [markdown]
# # 16.Strings in Python

# %% [markdown]
# ![Screenshot 2024-01-21 064920.png](attachment:3a6e9109-f577-48b1-8b45-552a267f9d93.png)

# %% [markdown]
# ![Screenshot 2024-01-21 065214.png](attachment:9e40b957-eb72-42c1-ad0e-e428d4f9d21a.png)

# %% [markdown]
# ![Screenshot 2024-01-21 065512.png](attachment:fb0069ca-df86-4931-8b41-562d9024418b.png)

# %% [markdown]
# ![Screenshot 2024-01-21 065839.png](attachment:4c792ed2-3a1a-48ee-887c-af1b03f7413c.png)

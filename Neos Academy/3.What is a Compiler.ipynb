# %% [markdown]
# # What is a Compiler?

# %% [markdown]
# ![C (1).png](attachment:24de6c0f-4f95-423e-9d68-412f38279534.png)

# %% [markdown]
# ![C (2).png](attachment:872aa49c-edee-4dc6-b27e-6175460b9ee4.png)

# %% [markdown]
# ![C (3).png](attachment:94721b60-becd-482a-971b-518bd2c29f82.png)

# %% [markdown]
# ![C (4).png](attachment:b811264c-ab3a-4b4a-8c1c-6a7e75f7c8cb.png)

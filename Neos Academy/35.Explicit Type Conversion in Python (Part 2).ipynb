# %% [markdown]
# # 35.Explicit Type Conversion in Python (Part 2)

# %% [markdown]
# ![image.png](attachment:df361128-ef80-4152-9ef3-91dcd6b5187b.png)

# %% [markdown]
# ![image.png](attachment:474ccf33-9790-4d72-9f15-9ede7df471b7.png)

# %% [markdown]
# ![image.png](attachment:9e504ec0-41d9-407a-b233-30ee8d9a059a.png)

# %% [markdown]
# ![image.png](attachment:80849ba0-057d-4da0-a4b9-53c6be6d1752.png)

# %% [markdown]
# ![image.png](attachment:05816e54-0550-443e-9894-3d6f5a19d352.png)

# %%
x = 10
y = 20
total = x + y
print("The total is : " + str(total))
# Out:
# The total is : 30

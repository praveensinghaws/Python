# %% [markdown]
# # 53.Comments in Python

# %% [markdown]
# ![image.png](attachment:aacaf2c7-b405-490f-a65e-11eec00abec3.png)

# %% [markdown]
# ![image.png](attachment:3e7c58be-4a2d-4468-af47-6ba24f040f88.png)

# %% [markdown]
# ![image.png](attachment:13b8de04-0421-4a1e-b542-6f098dbe0bd8.png)

# %% [markdown]
# ![image.png](attachment:46c29f4f-d9f8-46b2-8012-9c2f323cc8e9.png)

# %% [markdown]
# ![image.png](attachment:5aac346e-dd85-4efa-baf4-dae2717993f5.png)

# %% [markdown]
# ![image.png](attachment:f189496c-01c4-4b19-a30d-dadd2d95919e.png)

# %% [markdown]
# ![image.png](attachment:d6c8b1b6-6a12-40f6-88ae-894027db5756.png)

# %% [markdown]
# ![image.png](attachment:1fa00bce-03d4-4c59-8cb2-8130daf013c1.png)

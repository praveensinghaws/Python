# %% [markdown]
# # 59.Input a List using Loops in Python

# %% [markdown]
# ![image.png](attachment:2f570ef7-55a1-4bd5-9315-e9216504cb7d.png)

# %% [markdown]
# ![image.png](attachment:6adb2572-d148-4dc8-8b34-77bd1325d16f.png)

# %% [markdown]
# ![image.png](attachment:26b9385d-afb8-4294-8eaf-6958e3521dc2.png)

# %% [markdown]
# ![image.png](attachment:6ae10161-fd5e-4535-89ce-51d96cd6806f.png)

# %% [markdown]
# ![image.png](attachment:551196a3-3224-415e-8952-6ada06476bc7.png)

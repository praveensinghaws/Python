# %% [markdown]
# # 70.Copying a Dictionary in Python

# %% [markdown]
# ![image.png](attachment:915c9534-b821-4ad1-9cfc-1ca1f549bf73.png)

# %% [markdown]
# ![image.png](attachment:fee210ea-04bb-4f10-b9da-b2c4284ea72a.png)

# %% [markdown]
# ![image.png](attachment:74f97a17-8064-435e-888a-54cebbc2f378.png)

# %% [markdown]
# ![image.png](attachment:7883fe6b-8123-4d95-b419-5d5d6ac9e84a.png)

# %% [markdown]
# ![image.png](attachment:c90189f1-653f-46a4-a211-392709dfced4.png)

# %% [markdown]
# ![image.png](attachment:2561fabe-ec0b-4b7c-8d4c-77cfc4c7b126.png)

# %% [markdown]
# ![image.png](attachment:05fecdc3-18f9-4e01-8972-55d5d3239eb5.png)

# %% [markdown]
# ![image.png](attachment:bf46fa99-bed2-40f2-a660-4fc289921265.png)

# %% [markdown]
# ![image.png](attachment:5fce9812-63e8-4eee-a88b-fccd5a20637e.png)

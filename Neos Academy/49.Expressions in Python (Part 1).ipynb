# %% [markdown]
# # 49.Expressions in Python (Part 1)

# %% [markdown]
# ![image.png](attachment:ce5ceddb-3787-45a7-b7ff-9e782e92ef9c.png)

# %% [markdown]
# ![image.png](attachment:6d920348-b2b2-468a-bd0f-37aef8e84fec.png)

# %% [markdown]
# ![image.png](attachment:c731a034-a1ac-40fd-b2c1-764be1d2c503.png)

# %% [markdown]
# ![image.png](attachment:e80532b4-f2f2-4a39-925a-e391bd62c79e.png)

# %% [markdown]
# ![image.png](attachment:3da2bb52-4564-401b-bd64-3e0bfd2376a1.png)

# %% [markdown]
# ![image.png](attachment:8a6b74e4-15df-459b-972f-de37d9df8a02.png)

# %% [markdown]
# ![image.png](attachment:6e6420da-e6d5-4979-aa57-69488ff6eebe.png)

# %% [markdown]
# ![image.png](attachment:18f6babb-33c8-4612-9fff-eefd7af06a05.png)

# %% [markdown]
# ![image.png](attachment:1b0c848d-2874-411c-a8c4-f34f22eb0126.png)

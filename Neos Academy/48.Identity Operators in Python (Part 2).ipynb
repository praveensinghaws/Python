# %% [markdown]
# # 48.Identity Operators in Python (Part 2)

# %% [markdown]
# ![image.png](attachment:f44f8973-479b-4f1e-a1fd-00a8c83304d3.png)

# %% [markdown]
# ![image.png](attachment:8147043f-271c-4e2b-8c87-ca1e6997f821.png)

# %% [markdown]
# ![image.png](attachment:828731f1-7423-488a-82a8-0817bafc6d0e.png)

# %% [markdown]
# ![image.png](attachment:948dcae6-7794-4b7d-9947-dc9bb9b2fcd5.png)

# %% [markdown]
# ![image.png](attachment:6a42ad95-49bb-4700-a186-9eb23c712b83.png)

# %% [markdown]
# ![image.png](attachment:f3131855-8142-403e-80ec-e99dcca2b731.png)

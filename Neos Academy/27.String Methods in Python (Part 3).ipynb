# %% [markdown]
# # 27.String Methods in Python (Part 3)

# %% [markdown]
# ![Screenshot 2024-01-24 075055.png](attachment:fb2fea9a-62c2-47dd-949a-efca215f7fca.png)

# %% [markdown]
# ![Screenshot 2024-01-24 075219.png](attachment:04df3605-1656-446c-aadf-b4e60066e15f.png)

# %% [markdown]
# ![Screenshot 2024-01-24 075520.png](attachment:9866c009-3a39-4f61-9349-3c8bf6428b7e.png)

# %% [markdown]
# ![Screenshot 2024-01-24 075612.png](attachment:1892b488-e4fb-43c5-a4c2-14315d4e6492.png)

# %%
"Hello! I am Jaspreet".rsplit()
# Out:
# ['Hello!', 'I', 'am', 'Jaspreet']

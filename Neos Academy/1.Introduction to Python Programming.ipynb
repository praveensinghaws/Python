# %% [markdown]
# # 1.Introduction to Python Programming

# %% [markdown]
# ![A (1).png](attachment:3b47554d-7a25-45ca-ab66-869517da89d3.png)

# %% [markdown]
# ![A (2).png](attachment:99594daf-ada1-47e2-8f3e-4c7bee319194.png)

# %% [markdown]
# ![A (3).png](attachment:6c27b095-1759-40e8-a73c-30ea5c69df68.png)

# %% [markdown]
# ![A (4).png](attachment:08a2d83c-e9a1-486f-bcdc-223f1076eea2.png)

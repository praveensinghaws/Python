# %% [markdown]
# # 28.String Methods in Python (Part 4)

# %% [markdown]
# ## separator.Join() Method

# %% [markdown]
# ![Screenshot 2024-01-24 075854.png](attachment:55b4f230-9c1f-4ae1-9880-8f8ceff0c77f.png)

# %% [markdown]
# ![Screenshot 2024-01-24 080348.png](attachment:bedeb3d3-e1ed-43c2-9f12-c828555049b9.png)

# %% [markdown]
# ![Screenshot 2024-01-24 080603.png](attachment:ac52bbef-b6ec-462f-8e07-94c18907a64d.png)

# %% [markdown]
# ![Screenshot 2024-01-24 080719.png](attachment:746374f9-4feb-49c1-af0c-15b3643d9eef.png)

# %% [markdown]
# ![Screenshot 2024-01-24 081250.png](attachment:d4cc4497-656b-41a8-91f8-93399378109c.png)

# %% [markdown]
# ## replace() Method

# %% [markdown]
# ![Screenshot 2024-01-24 081706.png](attachment:3ce9e4e8-1fb6-410d-8155-e118c8e314cc.png)

# %% [markdown]
# ![Screenshot 2024-01-24 081916.png](attachment:fe477ad4-89a4-4f83-928a-0cf2cdd8795f.png)

# %% [markdown]
# ![Screenshot 2024-01-24 081954.png](attachment:7c915bf6-1772-485f-b21d-f2e9c5ad2cb0.png)

# %%
s = "Neos3Academy3is3the3best3Academy."
s.replace('3',' ')
# Out:
# 'Neos Academy is the best Academy.'

# %% [markdown]
# ![Screenshot 2024-01-24 082207.png](attachment:62781aaf-68d1-48d0-9a90-07f553229c4b.png)

# %%
# In this example, map(str, alist) converts each integer in the list to a string, and then join concatenates them without any space between them.
alist = [1, 2]
result = ''.join(map(str, alist))
print(result)
# Out:
# 12

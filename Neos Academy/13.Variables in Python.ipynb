# %% [markdown]
# # 13.Variables in Python

# %% [markdown]
# ![Screenshot 2024-01-21 054732.png](attachment:56dc15fa-67b5-4c60-a2f7-bfd61c80b5ce.png)

# %% [markdown]
# ![Screenshot 2024-01-21 055126.png](attachment:9d576b94-fe92-4b53-98a4-1375ab82e5e0.png)

# %% [markdown]
# ![Screenshot 2024-01-21 062345.png](attachment:a6527656-a196-40d7-bcc5-6fe6249d49ff.png)

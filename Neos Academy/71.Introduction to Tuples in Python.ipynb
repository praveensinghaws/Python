# %% [markdown]
# # 71.Introduction to Tuples in Python

# %% [markdown]
# ![image.png](attachment:f9e53d5f-76dd-4b23-8e11-703afcd115f5.png)

# %% [markdown]
# ![image.png](attachment:1cbec8f0-0f41-4711-9e46-fc8a4b0da861.png)

# %% [markdown]
# ![image.png](attachment:0dce4179-50c9-4e83-adb8-301e10e07d81.png)

# %% [markdown]
# ![image.png](attachment:ba8538bf-534d-4935-a185-789325982813.png)

# %% [markdown]
# ![image.png](attachment:74e498e6-3a34-4d19-808d-dab870894b30.png)

# %% [markdown]
# ![image.png](attachment:d2cb2f56-406d-4b46-acbc-2bb412fdc243.png)

# %% [markdown]
# ![image.png](attachment:ba947efc-0dc3-4c3a-9494-0bb22da77915.png)

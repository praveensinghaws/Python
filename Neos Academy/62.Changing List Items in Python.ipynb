# %% [markdown]
# # 62.Changing List Items in Python

# %% [markdown]
# ![image.png](attachment:c1adb399-ab9c-4c7c-82cf-fc0629f28ca4.png)

# %% [markdown]
# ![image.png](attachment:82becf8f-d13b-4ebf-b2aa-509b923d5848.png)

# %% [markdown]
# ![image.png](attachment:9b02bcd8-4481-4202-b4c6-dbacb6a5bf32.png)

# %% [markdown]
# ![image.png](attachment:27ead005-a264-484a-ace0-70bcf3a4d0e2.png)

# %% [markdown]
# ![image.png](attachment:4c187d60-02da-4f9b-8e5e-7b45a1c985d0.png)

# %% [markdown]
# ![image.png](attachment:8276d859-a673-47d5-8235-6d8a4e99c240.png)

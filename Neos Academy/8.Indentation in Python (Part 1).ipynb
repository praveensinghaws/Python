# %% [markdown]
# # 8.Indentation in Python (Part 1)

# %% [markdown]
# ![Screenshot 2024-01-20 090114.png](attachment:1c41cd2b-0124-4724-9c71-78b11304c25b.png)

# %% [markdown]
# ![Screenshot 2024-01-20 090544.png](attachment:bfaace00-2bf0-4c8b-9472-5933b7bcdc93.png)

# %%
# Assign the value 'Sam' to the variable 'name'
name = 'Sam'

# Check if the value of 'name' is equal to 'Sam'
if name == 'Sam':
    print('Hello Sam')
else:
    # If the value of 'name' is not 'Sam'
    print('Hello dude')

# Print a message regardless of the condition
print('How are you')
# Out:
# Hello Sam
# How are you

# %% [markdown]
# ![Screenshot 2024-01-20 090900.png](attachment:080184a6-c5b0-4506-ab6d-92aeb1705485.png)

# %% [markdown]
# # 29.String Methods in Python (Part 5)

# %% [markdown]
# ![Screenshot 2024-01-24 082927.png](attachment:c2cf82ad-bd80-4279-8f05-5e7b077588e3.png)

# %% [markdown]
# ![Screenshot 2024-01-24 083205.png](attachment:137bd90d-1b2f-4435-bad3-719f98452b76.png)

# %% [markdown]
# ![Screenshot 2024-01-24 083445.png](attachment:799eefa7-3b54-4815-8c2d-1c1b5814c1c3.png)

# %% [markdown]
# ![Screenshot 2024-01-24 083918.png](attachment:11c967c8-7392-49f6-b71d-5c2b706947cc.png)

# %% [markdown]
# ## If you want to capitalize each word in a string, you can use the title() method. Here's an example:

# %%
# If you want to capitalize each word in a string, you can use the title() method. Here's an example:
str1 = "this is a sample string"
result = str1.title()
print(result)
# Out:
# This Is A Sample String

# %% [markdown]
# ![Screenshot 2024-01-24 084622.png](attachment:30dfa2a8-e1b1-479b-b63c-b2942c01c361.png)

# %% [markdown]
# ![image.png](attachment:782da646-656b-431e-ab1b-23f552a97768.png)

# %% [markdown]
# ![image.png](attachment:598e5c66-8c82-4481-a054-c21a53f8a4e2.png)

# %% [markdown]
# ![image.png](attachment:07037a5a-9d51-485a-b1dc-c1efe8ac5079.png)

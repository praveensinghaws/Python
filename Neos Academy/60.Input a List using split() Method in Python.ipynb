# %% [markdown]
# # 60.Input a List using split() Method in Python

# %% [markdown]
# ![image.png](attachment:0671fe68-3c10-4840-9799-0b7294d76a97.png)

# %% [markdown]
# ![image.png](attachment:a9d2bfaa-f30c-44b2-8190-b841f2269a75.png)

# %% [markdown]
# ![image.png](attachment:7841d8a9-0c57-428a-b325-5de8fd99ee73.png)

# %% [markdown]
# ![image.png](attachment:097ed2a3-7415-4499-93cb-fec33fa7f7ab.png)

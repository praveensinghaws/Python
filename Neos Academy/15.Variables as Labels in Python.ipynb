# %% [markdown]
# # 15.Variables as Labels in Python

# %% [markdown]
# ![Screenshot 2024-01-21 063637.png](attachment:0ba8e260-e5a2-4f3d-adc3-c4125d58f1a1.png)

# %% [markdown]
# ![Screenshot 2024-01-21 063705.png](attachment:4d8325cf-c9cc-4ad3-97af-a256de4909b2.png)

# %% [markdown]
# ![Screenshot 2024-01-21 063935.png](attachment:9fd985ba-e37a-4dd7-a0ae-aeba8caa0748.png)

# %% [markdown]
# ![Screenshot 2024-01-21 064150.png](attachment:1584d74e-051a-4f3e-8ddc-2a0978a49f43.png)

# %% [markdown]
# ![Screenshot 2024-01-21 064634.png](attachment:c7acc894-4577-40ea-a157-8dff9b61d95a.png)

# %% [markdown]
# ![Screenshot 2024-01-21 064702.png](attachment:034c43fc-4431-4139-9d97-f7516a199fed.png)

# %% [markdown]
# # 25.String Methods in Python (Part 1)

# %% [markdown]
# ![Screenshot 2024-01-23 183822.png](attachment:09aa10e0-eb0a-413a-9bd6-37c613f9e238.png)

# %% [markdown]
# ![Screenshot 2024-01-24 071231.png](attachment:00f0d744-1f28-46f5-85ad-4cd6ebd396cd.png)

# %% [markdown]
# ![Screenshot 2024-01-24 071350.png](attachment:0db22931-c106-4183-bb67-2478da562f94.png)

# %% [markdown]
# ![Screenshot 2024-01-24 071514.png](attachment:d4185ee7-9e9c-4c01-8731-fd9569ac2159.png)

# %% [markdown]
# ![Screenshot 2024-01-24 071828.png](attachment:de353ce6-1465-4879-9388-7980d14f3a0b.png)

# %% [markdown]
# ![Screenshot 2024-01-24 071850.png](attachment:3eb1b20a-a8fe-424f-88e6-b0bb2007e9b3.png)

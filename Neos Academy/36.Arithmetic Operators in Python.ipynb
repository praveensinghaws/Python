# %% [markdown]
# # 36.Arithmetic Operators in Python

# %% [markdown]
# ![image.png](attachment:d8b1fa04-9018-477f-b266-21a66f706f3d.png)

# %% [markdown]
# ![image.png](attachment:c9342500-965f-4bf7-be75-a6020bf83909.png)

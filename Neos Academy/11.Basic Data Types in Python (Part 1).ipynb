# %% [markdown]
# # 11.Basic Data Types in Python (Part 1)

# %% [markdown]
# ![Screenshot 2024-01-20 093954.png](attachment:7d8c7c63-0ebc-4703-9b21-7bc85c5ec69f.png)

# %% [markdown]
# ![Screenshot 2024-01-21 051448.png](attachment:aabbb8d9-673c-4474-a4af-1f9c43f07a9f.png)

# %% [markdown]
# ![Screenshot 2024-01-21 051929.png](attachment:1e46818d-0068-4a15-9a3f-e42915514be6.png)

# %% [markdown]
# ![Screenshot 2024-01-21 052102.png](attachment:ba1ffb0b-c80a-47ad-991d-20f40f956995.png)

# %% [markdown]
# ![Screenshot 2024-01-21 052530.png](attachment:ca611111-de9b-42e7-ac7a-3115c608e1e4.png)

# %% [markdown]
# ![Screenshot 2024-01-21 052830.png](attachment:bf7a46bd-d6e8-4328-8da1-fd665987d2bc.png)

# %% [markdown]
# ![Screenshot 2024-01-21 052954.png](attachment:442382c3-2e6b-4ee7-b9df-7ea95488e6aa.png)

# %% [markdown]
# ![Screenshot 2024-01-21 053128.png](attachment:75b31069-24c8-4ca9-bd9e-c5a05e7f2f0c.png)

# %% [markdown]
# # 69.Removing Dictionary Items in Python

# %% [markdown]
# ![image.png](attachment:e472cf5d-feae-40ea-a36c-9e65d0000194.png)

# %% [markdown]
# ![image.png](attachment:1e21d040-2131-4364-9729-012216da9b8d.png)

# %% [markdown]
# ![image.png](attachment:4e01aef9-0059-4a01-9641-d6e597bf670f.png)

# %% [markdown]
# ![image.png](attachment:6deb81c7-643e-4b0b-90bd-eab50f0f7cfa.png)

# %% [markdown]
# ![image.png](attachment:1511087e-a6b6-463f-abdb-16e75b842597.png)

# %% [markdown]
# ![image.png](attachment:69d58e99-f23c-4979-a66f-47ecd372ed4e.png)

# %% [markdown]
# ![image.png](attachment:71ab8f8a-2176-4b21-9b4d-fd5c17a825dc.png)

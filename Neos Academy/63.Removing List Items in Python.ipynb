# %% [markdown]
# # 63.Removing List Items in Python

# %% [markdown]
# ![image.png](attachment:91316fd0-fed3-48b1-a4e9-9f0ebb1b1058.png)

# %% [markdown]
# ![image.png](attachment:3b50e2e7-b490-4f06-b05e-f4364c7e60ae.png)

# %% [markdown]
# ![image.png](attachment:9b6d9dad-409c-474a-a18f-a72a22aa65e4.png)

# %% [markdown]
# ![image.png](attachment:af402df6-a106-4e28-a1bf-550368e1915d.png)

# %% [markdown]
# ![image.png](attachment:f5436aa7-548f-4976-89b0-0d673577b355.png)

# %% [markdown]
# ![image.png](attachment:4d9e7051-4e20-4372-8e53-891ee2ab7fe6.png)

# %% [markdown]
# ![image.png](attachment:12e4ce6b-b4cc-4993-a28e-c4b598f50b96.png)

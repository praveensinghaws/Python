# %% [markdown]
# # 51.Statements in Python (Part 1)

# %% [markdown]
# ![image.png](attachment:96cd0b24-7408-430d-a189-6ad221130452.png)

# %% [markdown]
# ![image.png](attachment:9fe1fb1a-c63b-479e-b132-86f38daa1e94.png)

# %% [markdown]
# ![image.png](attachment:3d96807d-6424-45a7-b899-223076563ba8.png)

# %% [markdown]
# ![image.png](attachment:9b340562-5dab-4613-8649-277da8246464.png)

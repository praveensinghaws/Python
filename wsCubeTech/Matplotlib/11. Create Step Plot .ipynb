# %% [markdown]
# ![image.png](attachment:53e875e3-396f-459c-aaba-508d86e8bffc.png)
#
# ![image.png](attachment:b3d600df-4efb-4e23-b5f3-c2591a7e721b.png)

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Creating a step plot
plt.step(x, y, where='mid', color='r', marker='o', ms=10, mfc='c', label='Python')

# Title and Axes labels
plt.title('Step Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Legend at the upper left corner (loc=2)
plt.legend(loc=2)

# Displaying grid
plt.grid()

# Show the plot
plt.show()

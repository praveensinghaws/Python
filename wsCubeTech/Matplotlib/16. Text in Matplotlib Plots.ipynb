# %% [markdown]
# ![image.png](attachment:ee13986b-ac4c-4815-8b57-e8a1368027f7.png)
#
# ![image.png](attachment:f80c0cad-77ea-4802-80c9-314e10fabb4b.png)

# %%
import matplotlib.pyplot as plt

# Set the figure size
fig = plt.figure(figsize=(12, 4))

# Plot 1: Line Chart
x1 = [1, 2, 3, 4, 5]
y1 = [3, 1, 5, 2, 6]
title_color = ['r', 'g', 'b']

plt.subplot(1, 3, 1)
plt.plot(x1, y1, color='c')
plt.title('Line Chart - One', fontsize=15, fontweight='bold', color=title_color[0])
plt.xlabel('X-axis', fontsize=10, fontweight='bold', color=title_color[0])
plt.ylabel('Y-axis', fontsize=10, fontweight='bold', color=title_color[0])
plt.xlim(0, 7)
plt.ylim(0, 7)
plt.text(2, 6, "Power-BI", fontsize=13, fontweight='bold', color=title_color[0], style='italic', bbox={"facecolor": 'y'})
plt.annotate("Python", xy=(2, 1), xytext=(4, 1), arrowprops={'facecolor': 'k', 'shrink': 0.1})  # Annotate Python with arrow

# Plot 2: Line Chart
x2 = [1, 2, 3, 4]
y2 = [3, 1, 4, 2]
plt.subplot(1, 3, 2)
plt.plot(x2, y2, color='c')
plt.title('Line Chart - Two', fontsize=15, fontweight='bold', color=title_color[1])
plt.xlabel('X-axis', fontsize=10, fontweight='bold', color=title_color[1])
plt.ylabel('Y-axis', fontsize=10, fontweight='bold', color=title_color[1])
plt.xticks(x2, labels=['Python', 'C', 'C++', 'Java'])
plt.yticks(y2)
plt.text(1.3, 3.5, "Programming", fontsize=13, fontweight='bold', color=title_color[0], style='italic',
         bbox={"facecolor": 'y'})
plt.annotate("C++", xy=(1, 3), xytext=(2, 2), arrowprops={'facecolor': 'k', 'shrink': 0.1})  # Annotate C++ with arrow

# Plot 3: Line Chart
x3 = [1, 2, 3, 4]
y3 = [3, 1, 4, 2]
plt.subplot(1, 3, 3)
plt.plot(x3, y3, color='c')
plt.title('Line Chart - Three', fontsize=15, fontweight='bold', color=title_color[2])
plt.xlabel('X-axis', fontsize=10, fontweight='bold', color=title_color[2])
plt.ylabel('Y-axis', fontsize=10, fontweight='bold', color=title_color[2])
plt.axis([0, 7, 0, 6])  # Set custom axis limits
plt.text(4, 5, "Sql-Server", fontsize=13, fontweight='bold', color=title_color[0], style='italic',
         bbox={"facecolor": 'y'})
plt.annotate("PostgreSQL", xy=(3, 4), xytext=(5, 4), arrowprops={'facecolor': 'k', 'shrink': 0.1})  # Annotate PostgreSQL with arrow

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Set the figure size
fig = plt.figure(figsize=(12, 4))

# Plot 1: Line Chart
x1 = [1, 2, 3, 4, 5]
y1 = [3, 1, 5, 2, 6]
title_color = ['r', 'g', 'b']

plt.subplot(1, 3, 1)
plt.plot(x1, y1, color='c')
plt.title('Line Chart - One', fontsize=15, fontweight='bold', color=title_color[0])
plt.xlabel('X-axis', fontsize=10, fontweight='bold', color=title_color[0])
plt.ylabel('Y-axis', fontsize=10, fontweight='bold', color=title_color[0])
plt.xlim(0, 7)
plt.ylim(0, 7)
plt.text(2, 6, "Power-BI", fontsize=13, fontweight='bold', color=title_color[0], style='italic', bbox={"facecolor": 'y'})
plt.annotate("Python", xy=(2, 1), xytext=(4, 1), arrowprops={'facecolor': 'k', 'shrink': 0.1})  # Annotate Python with arrow
plt.legend('UP', loc=5, facecolor='pink', edgecolor='r', framealpha=0.8, shadow=True)

# Plot 2: Line Chart
x2 = [1, 2, 3, 4]
y2 = [3, 1, 4, 2]
plt.subplot(1, 3, 2)
plt.plot(x2, y2, color='c')
plt.title('Line Chart - Two', fontsize=15, fontweight='bold', color=title_color[1])
plt.xlabel('X-axis', fontsize=10, fontweight='bold', color=title_color[1])
plt.ylabel('Y-axis', fontsize=10, fontweight='bold', color=title_color[1])
plt.xticks(x2, labels=['Python', 'C', 'C++', 'Java'])
plt.yticks(y2)
plt.text(1.3, 3.5, "Programming", fontsize=13, fontweight='bold', color=title_color[0], style='italic',
         bbox={"facecolor": 'y'})
plt.annotate("C++", xy=(1, 3), xytext=(2, 2), arrowprops={'facecolor': 'k', 'shrink': 0.1})  # Annotate C++ with arrow
plt.legend('MID', loc=5, facecolor='pink', edgecolor='r', framealpha=0.8, shadow=True)

# Plot 3: Line Chart
x3 = [1, 2, 3, 4]
y3 = [3, 1, 4, 2]
plt.subplot(1, 3, 3)
plt.plot(x3, y3, color='c')
plt.title('Line Chart - Three', fontsize=15, fontweight='bold', color=title_color[2])
plt.xlabel('X-axis', fontsize=10, fontweight='bold', color=title_color[2])
plt.ylabel('Y-axis', fontsize=10, fontweight='bold', color=title_color[2])
plt.axis([0, 7, 0, 6])  # Set custom axis limits
plt.text(4, 5, "Sql-Server", fontsize=13, fontweight='bold', color=title_color[0], style='italic',
         bbox={"facecolor": 'y'})
plt.annotate("PostgreSQL", xy=(3, 4), xytext=(5, 4), arrowprops={'facecolor': 'k', 'shrink': 0.1})  # Annotate PostgreSQL with arrow
plt.legend('DOWN', loc=5, facecolor='pink', edgecolor='r', framealpha=0.8, shadow=True)

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Set the figure size
fig = plt.figure(figsize=(12, 4))

# Plot 1: Line Chart
x1 = [1, 2, 3, 4, 5]
y1 = [3, 1, 5, 2, 6]
title_color = ['r', 'g', 'b']

line1, = plt.plot(x1, y1, color='c')
plt.title('Line Chart - One', fontsize=15, fontweight='bold', color=title_color[0])
plt.xlabel('X-axis', fontsize=10, fontweight='bold', color=title_color[0])
plt.ylabel('Y-axis', fontsize=10, fontweight='bold', color=title_color[0])
plt.xlim(0, 7)
plt.ylim(0, 7)
plt.text(2, 6, "Power-BI", fontsize=13, fontweight='bold', color=title_color[0], style='italic', bbox={"facecolor": 'y'})
plt.annotate("Python", xy=(2, 1), xytext=(4, 1), arrowprops={'facecolor': 'k', 'shrink': 0.1})  # Annotate Python with arrow

# Plot 2: Line Chart
x2 = [1, 2, 3, 4]
y2 = [3, 1, 4, 2]
line2, = plt.plot(x2, y2, color='c')
plt.title('Line Chart - Two', fontsize=15, fontweight='bold', color=title_color[1])
plt.xlabel('X-axis', fontsize=10, fontweight='bold', color=title_color[1])
plt.ylabel('Y-axis', fontsize=10, fontweight='bold', color=title_color[1])
plt.xticks(x2, labels=['Python', 'C', 'C++', 'Java'])
plt.yticks(y2)
plt.text(1.3, 3.5, "Programming", fontsize=13, fontweight='bold', color=title_color[0], style='italic',
         bbox={"facecolor": 'y'})
plt.annotate("C++", xy=(1, 3), xytext=(2, 2), arrowprops={'facecolor': 'k', 'shrink': 0.1})  # Annotate C++ with arrow

# Plot 3: Line Chart
x3 = [1, 2, 3, 4]
y3 = [3, 1, 4, 2]
line3, = plt.plot(x3, y3, color='c')
plt.title('Line Chart - Three', fontsize=15, fontweight='bold', color=title_color[2])
plt.xlabel('X-axis', fontsize=10, fontweight='bold', color=title_color[2])
plt.ylabel('Y-axis', fontsize=10, fontweight='bold', color=title_color[2])
plt.axis([0, 7, 0, 6])  # Set custom axis limits
plt.text(4, 5, "Sql-Server", fontsize=13, fontweight='bold', color=title_color[0], style='italic',
         bbox={"facecolor": 'y'})
plt.annotate("PostgreSQL", xy=(3, 4), xytext=(5, 4), arrowprops={'facecolor': 'k', 'shrink': 0.1})  # Annotate PostgreSQL with arrow

# Set up legend with proper labels
plt.legend([line1, line2, line3], ['UP', 'MID', 'DOWN'], loc='upper left', facecolor='pink', edgecolor='r', framealpha=0.8, shadow=True)

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

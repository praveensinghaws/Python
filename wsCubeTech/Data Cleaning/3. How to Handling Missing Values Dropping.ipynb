# %% [markdown]
#  ![image.png](attachment:6b15b718-de8d-4156-a3e8-0a23650a373b.png)

# %%
# Importing the Pandas library as pd
import pandas as pd

# Importing the Seaborn library as sns
import seaborn as sns

# Importing the Matplotlib library for plotting
import matplotlib.pyplot as plt

# Reading the CSV file "loan.csv" into a DataFrame named df
df = pd.read_csv("loan.csv")

# Displaying the first three rows of the DataFrame
df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
# Displaying the dimensions (number of rows and columns) of the DataFrame
df.shape
# Out:
# (614, 13)

# %%
# Counting the number of missing values in each column of the DataFrame
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# Creating a heatmap to visualize missing values in the DataFrame using Seaborn
sns.heatmap(df.isnull())

# Displaying the plot
plt.show()

# %%
# Dropping the column "Credit_History" from the DataFrame
df.drop(columns=["Credit_History"], inplace=True)

# %%
# Displaying the dimensions (number of rows and columns) of the DataFrame
df.shape
# Out:
# (614, 12)

# %%
# Displaying the column names of the DataFrame
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
# Creating a heatmap to visualize missing values in the DataFrame using Seaborn
sns.heatmap(df.isnull())

# Displaying the plot
plt.show()

# %%
# Removing rows with any missing values from the DataFrame
df.dropna(inplace=True)

# %%
# Counting the number of missing values in each column of the DataFrame
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
# Creating a heatmap to visualize missing values in the DataFrame using Seaborn
sns.heatmap(df.isnull())

# Displaying the plot
plt.show()

# %%
# Displaying the dimensions (number of rows and columns) of the DataFrame
df.shape
# Out:
# (523, 12)

# %%
# Calculating the percentage of data loss after removing rows with missing values
loss_data_percentage= ((614 - 523) / 613) * 100
loss_data_percentage
# Out:
# 14.845024469820556

# %% [markdown]
# ![image.png](attachment:28b2ccb1-95b3-4098-96b0-e27699ffcb78.png)
#
# ![image.png](attachment:44280dfb-4cbb-432e-a809-2d64616b6e40.png)

# %%
# Importing the Pandas library as pd
import pandas as pd

# Importing the Seaborn library as sns
import seaborn as sns

# Importing the Matplotlib library for plotting
import matplotlib.pyplot as plt

# Reading the CSV file "loan.csv" into a DataFrame named df
df = pd.read_csv("loan.csv")

# Displaying the first three rows of the DataFrame
df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# Create subplots with 2 rows and 1 column
fig, axes = plt.subplots(2, 1, figsize=(12, 8))

# Boxplot for the "CoapplicantIncome" column with a different color
sns.boxplot(x="CoapplicantIncome", data=df, ax=axes[0], color="salmon")
axes[0].set_title("Boxplot - CoapplicantIncome")

# Distribution plot for the "CoapplicantIncome" column with a different color
sns.histplot(df["CoapplicantIncome"], ax=axes[1], kde=True, color="c")
axes[1].set_title("Distribution Plot - CoapplicantIncome")

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
# Importing the MinMaxScaler from scikit-learn
from sklearn.preprocessing import MinMaxScaler

# Creating an instance of MinMaxScaler
ms = MinMaxScaler()

# Fitting the MinMaxScaler on the "CoapplicantIncome" column
ms.fit(df[["CoapplicantIncome"]])

# Transforming the data and creating a new column "CoapplicantIncome_Min_Max"
df["CoapplicantIncome_Min_Max"] = ms.transform(df[["CoapplicantIncome"]])

# Displaying the first three rows of the DataFrame
df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status  CoapplicantIncome_Min_Max
# 0             1.0         Urban           Y                   0.000000
# 1             1.0         Rural           N                   0.036192
# 2             1.0         Urban           Y                   0.000000

# %%
# Create subplots with 2 rows and 1 column
fig, axes = plt.subplots(2, 1, figsize=(12, 8))

# Distribution plot for the "CoapplicantIncome" column with a different color
sns.histplot(df["CoapplicantIncome"], ax=axes[0], kde=True, color="skyblue")
axes[0].set_title("Before - Distribution Plot - CoapplicantIncome")

# Distribution plot for the "CoapplicantIncome_Min_Max" column with a different color
sns.histplot(df["CoapplicantIncome_Min_Max"], ax=axes[1], kde=True, color="salmon")
axes[1].set_title("After - Distribution Plot - CoapplicantIncome_Min_Max")

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
